# %%
import pandas as pd 
import numpy as np
import hashlib
from csv import reader
import re
pd.set_option('display.max_colwidth', None)

# %%
def hash_str(to_hash): 
    stringToHash = to_hash.encode()
    return hashlib.sha256(stringToHash).hexdigest()

# %%
def process_lbl(line_list): 
#     name_dict = {}
#     data_dict = {}
#     name =''
    data_list = []
    i = 0
    name_line = ''
    while (i < len(line_list)): 
#         doc = ''
#         test = ''
#         test_time = 0
#         regex = ''
#         n_trans = 0
#         n_states = 0
        if i+1 < len(line_list) and '---------,---------,---------,---------' in line_list[i+1]:
            name_line = line_list[i].strip('\n')
#             split_line = line_list[i].strip('\n').split(',')
#             doc = split_line[0]
#             test = split_line[1]
#             test_time = int(split_line[2])
#             regex = split_line[3]
#             n_trans = int(split_line[4])
#             n_states = int(splint_line[5])
                
        elif "---------,---------,---------,---------" in line_list[i]: 
            pass
        else: 
            for line in reader([name_line+','+line_list[i].strip()]):
                data_list.append(line)
        i = i + 1
    return data_list
#(name_dict, data_dict)

# %%
f = open("tests/results/pihole", "r")
lbl = [x for x in f]
f.close()

data = process_lbl(lbl)

# %%
df.iloc[6700:6705]
# Out:
#                  doc setup        time n_transitions n_states test_type  \
# 6700  mads.testi_128   nwr  1700244797             7        R         P
#
#       component   test val metric        regex
# 6700  prove+wit  11843  μs   None  ^mads\.,896

# %%
df = pd.DataFrame(data, columns = ['doc','setup','time','regex','n_transitions','n_states',
                                    'test_type','component','test','val','metric'])
# df['regex'] = df["regex1"]+","+df["regex2"]
#df.drop(['regex1','regex2'],axis=1, inplace=True)
df.val = df.val.astype(int)
df.head()
# Out:
#               doc setup        time  \
# 0  ad.stackov_128   nwr  1700242171
# 1  ad.stackov_128   nwr  1700242171
# 2  ad.stackov_128   nwr  1700242171
# 3  ad.stackov_128   nwr  1700242171
# 4  ad.stackov_128   nwr  1700242171
#
#                                                                                    regex  \
# 0  ^ad([sxv]?[0-9]*|system)[_.-]([^.[:space:]]+\.){1,}|[_.-]ad([sxv]?[0-9]*|system)[_.-]
# 1  ^ad([sxv]?[0-9]*|system)[_.-]([^.[:space:]]+\.){1,}|[_.-]ad([sxv]?[0-9]*|system)[_.-]
# 2  ^ad([sxv]?[0-9]*|system)[_.-]([^.[:space:]]+\.){1,}|[_.-]ad([sxv]?[0-9]*|system)[_.-]
# 3  ^ad([sxv]?[0-9]*|system)[_.-]([^.[:space:]]+\.){1,}|[_.-]ad([sxv]?[0-9]*|system)[_.-]
# 4  ^ad([sxv]?[0-9]*|system)[_.-]([^.[:space:]]+\.){1,}|[_.-]ad([sxv]?[0-9]*|system)[_.-]
#
#   n_transitions n_states test_type component                   test  \
# 0         12032       94         R         C    regex_normalization
# 1         12032       94         R        CG             generation
# ...
